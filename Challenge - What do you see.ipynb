# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('basket.csv')
df.head()
df.info()

# This data set contains statistics for 22,083 basketball players.
# These stats include games played, points, assists, rebounds etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22083 entries, 0 to 22082
# Data columns (total 17 columns):
# playerID          22083 non-null object
# GP                22083 non-null int64
# points            22083 non-null int64
# oRebounds         22083 non-null int64
# dRebounds         22083 non-null int64
# rebounds          22083 non-null int64
# assists           22083 non-null int64
# steals            22083 non-null int64
# blocks            22083 non-null int64
# turnovers         22083 non-null int64
# PF                22083 non-null int64
# fgAttempted       22083 non-null int64
# fgMade            22083 non-null int64
# ftAttempted       22083 non-null int64
# ftMade            22083 non-null int64
# threeAttempted    22083 non-null int64
# threeMade         22083 non-null int64
# dtypes: int64(16), object(1)
# memory usage: 2.8+ MB

# %%
plt.scatter(x=df['GP'], y=df['points'])
plt.xlabel('Games played')
plt.ylabel('points')
plt.title('Games played / points')
plt.show()

# This scatter plot show games played vs points.
# There is general positive correlation - more games result in more points.
# Some players who played many games didn't necessarily score many points.

# %%
df.corr()

# There is a strong correlation between points and attempts(.98).
# There is a medium correlation between points and blocks(.40).
# Some of the offensive players should get back on defense and block more.
# Out:
#                       GP    points  oRebounds  dRebounds  rebounds   assists  \
# GP              1.000000  0.741536   0.550502   0.586136  0.678239  0.612776
# points          0.741536  1.000000   0.538405   0.612480  0.743445  0.719297
# oRebounds       0.550502  0.538405   1.000000   0.907966  0.697206  0.265906
# dRebounds       0.586136  0.612480   0.907966   1.000000  0.722303  0.385923
# rebounds        0.678239  0.743445   0.697206   0.722303  1.000000  0.429920
# assists         0.612776  0.719297   0.265906   0.385923  0.429920  1.000000
# steals          0.598242  0.641088   0.599659   0.671556  0.428387  0.695436
# blocks          0.413255  0.403140   0.739887   0.763868  0.574230  0.153033
# turnovers       0.581673  0.670430   0.658197   0.732441  0.484089  0.632818
# PF              0.875314  0.784279   0.617004   0.633660  0.791297  0.577337
# fgAttempted     0.754611  0.980126   0.500425   0.577950  0.734320  0.729693
# ...

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(df.groupby('playerID').sum()['points'].iloc[:26], color='purple')
plt.ylabel('points')
plt.title('Points made')

plt.subplot(1, 2, 2)
plt.plot(df['assists'], color='green')
plt.ylabel('assists')
plt.title('Assists')
plt.show()

# I grouped the players, as the data included yearly information and players existed in multiple years.
# There were a few players that scored many points in their career, a sharp drop off, then the mid-tier players.
# The drop off in assists was less dramatic than that of points as the quality decreased.

# %%
plt.hist(df['points'],bins=50)
plt.xlabel('number of points')
plt.ylabel('number of players')
plt.title('Points Histogram')
plt.show()

average = np.mean(df['points'])
std_dev = np.std(df['points'])

print('average number of points = ', round(average,2))
print('standard deviation = ', round(std_dev,2))

# The histogram of points shows that there were many players that made few points, and few players that made many points.
# This data show that players averaged about 487 points per year.
# Out:
# average number of points =  487.11
# standard deviation =  499.2

# %%
plt.boxplot(df['points'])

median = np.median(df['points'])
print('The median number of points made per year =', median)

# The box plot shows that a bulk of the players made less than 1000 points.
# The number of outliers shows that superstars made a considerable amount of points more than the average player.
# Out:
# The median number of points made per year = 325.0
